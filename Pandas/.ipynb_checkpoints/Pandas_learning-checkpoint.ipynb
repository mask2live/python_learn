# %%
import pandas

# %%
data = pandas.read_csv("supermarkets/supermarkets.csv")

# %%
print(data)
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
data_excel = pandas.read_excel('supermarkets/supermarkets.xlsx')

# %%
data_excel
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
data_json = pandas.read_json('supermarkets/supermarkets.json')

# %%
data_json
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
data_txt = pandas.read_csv('supermarkets/supermarkets-commas.txt')

# %%
data_txt
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
data_txt2 = pandas.read_csv('supermarkets/supermarkets-semi-colons.txt')

# %%
data_txt2
# Out:
#         ID;Address;City;State;Country;Name;Employees
# 0  1;3666 21st St;San Francisco;CA 94114;USA;Made...
# 1  2;735 Dolores St;San Francisco;CA 94119;USA;Br...
# 2  3;332 Hill St;San Francisco;California 94114;U...
# 3  4;3995 23rd St;San Francisco;CA 94114;USA;Ben'...
# 4  5;1056 Sanchez St;San Francisco;California;USA...
# 5  6;551 Alvarado St;San Francisco;CA 94114;USA;R...

# %%
data_txt3 = pandas.read_csv('supermarkets/supermarkets-semi-colons.txt', sep=';')

# %%
data_txt3
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
# clean the header describe
data_txt4 = pandas.read_csv('supermarkets/supermarkets-semi-colons.txt', sep=';', header = None)
data_txt4
# Out:
#     0                1              2                 3        4  \
# 0  ID          Address           City             State  Country
# 1   1     3666 21st St  San Francisco          CA 94114      USA
# 2   2   735 Dolores St  San Francisco          CA 94119      USA
# 3   3      332 Hill St  San Francisco  California 94114      USA
# 4   4     3995 23rd St  San Francisco          CA 94114      USA
# 5   5  1056 Sanchez St  San Francisco        California      USA
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA
#
#               5          6
# 0          Name  Employees
# 1       Madeira          8
# 2   Bready Shop         15
# 3   Super River         25
# 4    Ben's Shop         10
# 5       Sanchez         12
# 6    Richvalley         20

# %%
# specified the columns names
data_txt4.columns = ['A', 'B', 'C', 'D', 'E', 'F', 'G']
data_txt4
# Out:
#     A                B              C                 D        E  \
# 0  ID          Address           City             State  Country
# 1   1     3666 21st St  San Francisco          CA 94114      USA
# 2   2   735 Dolores St  San Francisco          CA 94119      USA
# 3   3      332 Hill St  San Francisco  California 94114      USA
# 4   4     3995 23rd St  San Francisco          CA 94114      USA
# 5   5  1056 Sanchez St  San Francisco        California      USA
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA
#
#               F          G
# 0          Name  Employees
# 1       Madeira          8
# 2   Bready Shop         15
# 3   Super River         25
# 4    Ben's Shop         10
# 5       Sanchez         12
# 6    Richvalley         20

# %%
data_txt4.set_index('A')
# Out:
#                   B              C                 D        E             F  \
# A
# ID          Address           City             State  Country          Name
# 1      3666 21st St  San Francisco          CA 94114      USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119      USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114      USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114      USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California      USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114      USA    Richvalley
#
#             G
# A
# ID  Employees
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
data_txt4 = data_txt3
data_txt4
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
data_txt4.set_index('ID', inplace=True)

# %%
data_txt4
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
data_txt4.set_index('Name', inplace=True, drop=False)

# %%
data_txt4
# Out:
#                       Address           City             State Country  \
# Name
# Madeira          3666 21st St  San Francisco          CA 94114     USA
# Bready Shop    735 Dolores St  San Francisco          CA 94119     USA
#  Super River      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop       3995 23rd St  San Francisco          CA 94114     USA
# Sanchez       1056 Sanchez St  San Francisco        California     USA
# Richvalley    551 Alvarado St  San Francisco          CA 94114     USA
#
#                       Name  Employees
# Name
# Madeira            Madeira          8
# Bready Shop    Bready Shop         15
#  Super River   Super River         25
# Ben's Shop      Ben's Shop         10
# Sanchez            Sanchez         12
# Richvalley      Richvalley         20

# %%
# scope to display
data_txt4.loc["Madeira" : "Bready Shop", "Address":"City"]
# Out:
#                     Address           City
# Name
# Madeira        3666 21st St  San Francisco
# Bready Shop  735 Dolores St  San Francisco

# %%
# scope by index
data_txt4.iloc[1:3, 1:4]
# Out:
#                        City             State Country
# Name
# Bready Shop   San Francisco          CA 94119     USA
#  Super River  San Francisco  California 94114     USA

# %%
data_txt4.iloc[5,:]
# Out:
# Address      551 Alvarado St
# City           San Francisco
# State               CA 94114
# Country                  USA
# Name              Richvalley
# Employees                 20
# Name: Richvalley, dtype: object

# %%
data_txt4.iloc[5,0:3]
# Out:
# Address    551 Alvarado St
# City         San Francisco
# State             CA 94114
# Name: Richvalley, dtype: object

# %%
# delete columns and row

# 0 is meaning row
data_txt4.drop("Madeira", 0)
# Out:
#                       Address           City             State Country  \
# Name
# Bready Shop    735 Dolores St  San Francisco          CA 94119     USA
#  Super River      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop       3995 23rd St  San Francisco          CA 94114     USA
# Sanchez       1056 Sanchez St  San Francisco        California     USA
# Richvalley    551 Alvarado St  San Francisco          CA 94114     USA
#
#                       Name  Employees
# Name
# Bready Shop    Bready Shop         15
#  Super River   Super River         25
# Ben's Shop      Ben's Shop         10
# Sanchez            Sanchez         12
# Richvalley      Richvalley         20

# %%
# 1 is meaning column
data_txt4.drop(data_txt4.columns[0:3], 1)
# Out:
#              Country          Name  Employees
# Name
# Madeira          USA       Madeira          8
# Bready Shop      USA   Bready Shop         15
#  Super River     USA   Super River         25
# Ben's Shop       USA    Ben's Shop         10
# Sanchez          USA       Sanchez         12
# Richvalley       USA    Richvalley         20

# %%
### Adding and updating

# shape of the dataframe
data_txt4.shape
# Out:
# (6, 6)

# %%
# add content with the number of rows times

data_txt4.shape[0]*['Jack Ma']
# Out:
# ['Jack Ma', 'Jack Ma', 'Jack Ma', 'Jack Ma', 'Jack Ma', 'Jack Ma']

# %%
# add one column which named `Owner`
data_txt4['Owner'] = data_txt4.shape[0]*['Jack Ma']
data_txt4
# Out:
#                       Address           City             State Country  \
# Name
# Madeira          3666 21st St  San Francisco          CA 94114     USA
# Bready Shop    735 Dolores St  San Francisco          CA 94119     USA
#  Super River      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop       3995 23rd St  San Francisco          CA 94114     USA
# Sanchez       1056 Sanchez St  San Francisco        California     USA
# Richvalley    551 Alvarado St  San Francisco          CA 94114     USA
#
#                       Name  Employees    Owner
# Name
# Madeira            Madeira          8  Jack Ma
# Bready Shop    Bready Shop         15  Jack Ma
#  Super River   Super River         25  Jack Ma
# Ben's Shop      Ben's Shop         10  Jack Ma
# Sanchez            Sanchez         12  Jack Ma
# Richvalley      Richvalley         20  Jack Ma

# %%
## add one row

# exchange row and column
data4T = data_txt4.T
data4T
# Out:
# Name             Madeira     Bready Shop       Super River     Ben's Shop  \
# Address     3666 21st St  735 Dolores St       332 Hill St   3995 23rd St
# City       San Francisco   San Francisco     San Francisco  San Francisco
# State           CA 94114        CA 94119  California 94114       CA 94114
# Country              USA             USA               USA            USA
# Name             Madeira     Bready Shop       Super River     Ben's Shop
# Employees              8              15                25             10
# Owner            Jack Ma         Jack Ma           Jack Ma        Jack Ma
#
# Name               Sanchez       Richvalley
# Address    1056 Sanchez St  551 Alvarado St
# City         San Francisco    San Francisco
# State           California         CA 94114
# Country                USA              USA
# Name               Sanchez       Richvalley
# Employees               12               20
# Owner              Jack Ma          Jack Ma

# %%
data4T['NIO'] = ['Street of ShenNan', 'Shenzhen', 'Futian', 'China', 'NIO', 233, 'Johny Ma']
data4T
# Out:
# Name             Madeira     Bready Shop       Super River     Ben's Shop  \
# Address     3666 21st St  735 Dolores St       332 Hill St   3995 23rd St
# City       San Francisco   San Francisco     San Francisco  San Francisco
# State           CA 94114        CA 94119  California 94114       CA 94114
# Country              USA             USA               USA            USA
# Name             Madeira     Bready Shop       Super River     Ben's Shop
# Employees              8              15                25             10
# Owner            Jack Ma         Jack Ma           Jack Ma        Jack Ma
#
# Name               Sanchez       Richvalley                NIO
# Address    1056 Sanchez St  551 Alvarado St  Street of ShenNan
# City         San Francisco    San Francisco           Shenzhen
# State           California         CA 94114             Futian
# Country                USA              USA              China
# ...

# %%
data_txt4 = data4T.T
data_txt4
# Out:
#                         Address           City             State Country  \
# Name
# Madeira            3666 21st St  San Francisco          CA 94114     USA
# Bready Shop      735 Dolores St  San Francisco          CA 94119     USA
#  Super River        332 Hill St  San Francisco  California 94114     USA
# Ben's Shop         3995 23rd St  San Francisco          CA 94114     USA
# Sanchez         1056 Sanchez St  San Francisco        California     USA
# Richvalley      551 Alvarado St  San Francisco          CA 94114     USA
# NIO           Street of ShenNan       Shenzhen            Futian   China
#
#                       Name Employees     Owner
# Name
# Madeira            Madeira         8   Jack Ma
# Bready Shop    Bready Shop        15   Jack Ma
#  Super River   Super River        25   Jack Ma
# Ben's Shop      Ben's Shop        10   Jack Ma
# Sanchez            Sanchez        12   Jack Ma
# Richvalley      Richvalley        20   Jack Ma
# ...
